# %%
import sys

# !{sys.executable} -m pip install mediapipe
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#     --------------------------------------- 0.8/51.0 MB 4.8 MB/s eta 0:00:11
#    - -------------------------------------- 1.6/51.0 MB 4.7 MB/s eta 0:00:11
#    -- ------------------------------------- 2.6/51.0 MB 4.7 MB/s eta 0:00:11
#    -- ------------------------------------- 3.4/51.0 MB 4.5 MB/s eta 0:00:11
#    --- ------------------------------------ 4.2/51.0 MB 4.3 MB/s eta 0:00:11
#    --- ------------------------------------ 5.0/51.0 MB 4.3 MB/s eta 0:00:11
#    ---- ----------------------------------- 5.8/51.0 MB 4.1 MB/s eta 0:00:11
#    ---- ----------------------------------- 6.3/51.0 MB 4.1 MB/s eta 0:00:11
#    ----- ---------------------------------- 6.8/51.0 MB 4.0 MB/s eta 0:00:12
#    ----- ---------------------------------- 7.6/51.0 MB 3.9 MB/s eta 0:00:12
# ...

# %%
from cvzone.HandTrackingModule import HandDetector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from cvzone.HandTrackingModule import HandDetector
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\cvzone\HandTrackingModule.py:10
#       7 import math
#       9 import cv2
# ---> 10 import mediapipe as mp
#      13 class HandDetector:
#      14     """
#      15     Finds Hands using the mediapipe library. Exports the landmarks
#      16     in pixel format. Adds extra functionalities like finding how
#      17     many fingers are up or the distance between two fingers. Also
#      18     provides bounding box info of the hand found.
#      19     """
#
# ModuleNotFoundError: No module named 'mediapipe'
